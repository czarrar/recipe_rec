# %%
import os
os.chdir('/Users/czarrar/Dropbox/Circle/Jerb/recipe_rec/code')

# %%
# %matplotlib inline

import libs_recipe_recs
import numpy as np

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# We load in our prior model
recs = libs_recipe_recs.RecipeRec.load_model('z_model.p')

# %%
recs.recipes
# Out:
#        recipe_id  ave_rating  num_reviews  \
# 0         240488    4.764706           29
# 1         218939    4.571429           12
# 2          87211    4.625000          163
# 3         245714    4.500000            2
# 4         218545    4.605769           85
# ...          ...         ...          ...
# 45625     222886    3.500000            4
# 45626      25650    4.333333            3
# 45627      23544    3.615385           21
# 45628     170710    4.714286           19
# 45629      79774    4.500000            2
#
#                                           name  \
# 0            Pork Loin, Apples, and Sauerkraut
# 1             Foolproof Rosemary Chicken Wings
# 2                        Chicken Pesto Paninis
# 3                           Potato Bacon Pizza
# 4      Latin-Inspired Spicy Cream Chicken Stew
# ...                                        ...
# 45625                   Grateful Dead Cocktail
# 45626              Cheese Filling For Pastries
# 45627                           Peach Smoothie
# 45628                      Double Dare Peaches
# 45629               All-Purpose Marinara Sauce
#
#                                              ingredients  \
# 0      sauerkraut drained, Granny Smith apples sliced...
# 1      chicken wings, sprigs rosemary, head garlic, o...
# 2      focaccia bread quartered, prepared basil pesto...
# 3      red potatoes, strips bacon, Sauce:, heavy whip...
# 4      skinless boneless chicken breast halves, diced...
# ...                                                  ...
# 45625  fluid ounce tequila, fluid ounce vodka, fluid ...
# 45626  raisins, brandy, cream cheese, white sugar, al...
# 45627  sliced peaches drained, scoops vanilla ice cre...
# 45628  butter, habanero peppers, fresh peaches, brown...
# 45629  olive oil, bulb garlic, tomatoes chopped, dice...
#
#                                     img_path
# 0      ../data/RecSys/core_images/240488.jpg
# 1      ../data/RecSys/core_images/218939.jpg
# 2       ../data/RecSys/core_images/87211.jpg
# 3      ../data/RecSys/core_images/245714.jpg
# 4      ../data/RecSys/core_images/218545.jpg
# ...                                      ...
# 45625  ../data/RecSys/core_images/222886.jpg
# 45626   ../data/RecSys/core_images/25650.jpg
# 45627   ../data/RecSys/core_images/23544.jpg
# 45628  ../data/RecSys/core_images/170710.jpg
# 45629   ../data/RecSys/core_images/79774.jpg
#
# [45630 rows x 6 columns]
